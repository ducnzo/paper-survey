# %% [markdown]
# ### I.EfficientNet-B4-Ranger: A novel method for greenhouse cucumber disease recognition under natural complex environment
#
# #### Dataset:
# Cucumber leaf: PM, DM, PD, Healthy
# ![image-3.png](attachment:image-3.png)
# #### Result:
#
# 1. Compare in EfficientNet Architecture
# ![image.png](attachment:image.png)
# => Choose EfficientNetB4
#
# 2. Compartision of Optimizer
# ![image-2.png](attachment:image-2.png)
# => Choose Ranger => EfficientNetB4 + Ranger
#
# 3. Comparision of EfficientNetB4 + Ranger and other model
# ![image-4.png](attachment:image-4.png)
# => EfficientNetB4 + Ranger best

# %% [markdown]
# ### II. A comparative study of fine-tuning deep learning models for plant disease identification
#
# #### Dataset: PlantVillage
#
# #### Result
# pretrained: ImageNet, Cifar 10 and Cifar 100 classification.
#
# 1. Comparision of different model
# ![image.png](attachment:image.png)
# => DenseNets, ResNet and InceptionV4 better than VGG <p>
# DenseNets have: - least number of parameters
#                 - highest test accuracy
#                 - 121 layers
# Recommend: DenseNets.

# %% [markdown]
# ### III. Identifying plant diseases using deep transfer learning and enhanced lightweight network
#
#
# ### Dataset: 1000 plant disease images, which are composed of 500 rice disease images and 466
# maize disease images
# ![image-2.png](attachment:image-2.png)
#
# Symtomps
# ![image-3.png](attachment:image-3.png)
#
# ### Result
# ![image.png](attachment:image.png)
#
# Proposed model: ehanced MobileNetV2
#
# In the image, we can see MobileNetV2 owned high Test Accuracy with 98.97%, only behind proposed model.
#
# => Recommend: MobileNetV2

# %% [markdown]
# ### IV. Plant leaf disease classification using EfficientNet deep learning model
#
# #### Dataset:
# PlantVillage
#
# #### Result
#
# 1. Optimizer
# ![image.png](attachment:image.png)
#
# 2. On original dataset
# ![image-2.png](attachment:image-2.png)
# => EfficientNetB4
#
# 3. On augmented dataset
# ![image-3.png](attachment:image-3.png)
# => EfficientNetB5

# %% [markdown]
# ### V. Cucumber disease recognition using machine learning and transfer learning
#
# #### Dataset
# Self-collected dataset: cucumber
# ![image.png](attachment:image.png)
#
# #### Result
# 1.
# ![image-3.png](attachment:image-3.png)
#
# ![image-2.png](attachment:image-2.png)
#
# => MobileNetV2

# %% [markdown]
# ### VI. Cardamom Plant Disease Detection Approach Using EfficientNetV2
#
# #### Dataset:
# - 1724 cardamom plant leaf
# images of three classes, namely, Colletotrichum Blight and
# Phyllosticta Leaf Spot and healthy category.
# - Complex background of the images removed by extract-
# ing the multiscale features with U2-Net.
# ![image.png](attachment:image.png)
#
# #### Result
#
# 1. Following dataset
# ![image-2.png](attachment:image-2.png)
#
# 2. Following leaf disease
# ![image-3.png](attachment:image-3.png)
# ![image-4.png](attachment:image-4.png)
#
# 3. Comparision of proposed model with the state of the art methods.
# ![image-5.png](attachment:image-5.png)
#
# => EfficientNetV2
